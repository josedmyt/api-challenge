# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 649

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

City=[]
Cloudiness=[]
Country=[]
Date=[]
Humidity=[]
Lat=[]
Lng=[]
Max_Temp=[]
Wind_Speed=[]

print("Beginning Data Retrieval") 
print("-------------------------")

for city in cities:
    response = requests.get(query_url + city).json()
    time.sleep(0.5)
    if response['cod']== 200: 
        City.append(response['name'])
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed'])     
        print(f"Processing Record Number {cities.index(city)} for : {city}")
    else:
        print(f"Record Number {cities.index(city)} not found for : {city}")
print("Finished Data Retrieval")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record Number 0 for : carnarvon
# Processing Record Number 1 for : rio grande
# Processing Record Number 2 for : brae
# Processing Record Number 3 for : xuanzhou
# Processing Record Number 4 for : tomatlan
# Processing Record Number 5 for : praya
# Processing Record Number 6 for : waddan
# Processing Record Number 7 for : kapaa
# Processing Record Number 8 for : yulara
# Processing Record Number 9 for : champerico
# Record Number 10 not found for : turtkul
# Processing Record Number 11 for : busselton
# Processing Record Number 12 for : ponta do sol
# Processing Record Number 13 for : yellowknife
# Processing Record Number 14 for : ravar
# Processing Record Number 15 for : punta arenas
# Processing Record Number 16 for : la macarena
# Processing Record Number 17 for : qaanaaq
# Processing Record Number 18 for : anloga
# Processing Record Number 19 for : albany
# Processing Record Number 20 for : aripuana
# Record Number 21 not found for : belushya guba
# Processing Record Number 22 for : nouakchott
# Processing Record Number 23 for : hithadhoo
# Processing Record Number 24 for : bentiu
# Processing Record Number 25 for : arraial do cabo
# Processing Record Number 26 for : port alfred
# Processing Record Number 27 for : vao
# Processing Record Number 28 for : barcelona
# Processing Record Number 29 for : atuona
# Processing Record Number 30 for : mar del plata
# Processing Record Number 31 for : panaba
# Processing Record Number 32 for : varhaug
# Record Number 33 not found for : amderma
# Processing Record Number 34 for : murgab
# Processing Record Number 35 for : tortoli
# Processing Record Number 36 for : arinos
# Processing Record Number 37 for : cehegin
# Processing Record Number 38 for : katherine
# Record Number 39 not found for : toliary
# Processing Record Number 40 for : ushuaia
# Processing Record Number 41 for : mulchen
# Processing Record Number 42 for : salalah
# Processing Record Number 43 for : jamestown
# Processing Record Number 44 for : cabo san lucas
# Processing Record Number 45 for : kodiak
# Processing Record Number 46 for : ranot
# Processing Record Number 47 for : akyab
# Processing Record Number 48 for : rikitea
# Processing Record Number 49 for : port hawkesbury
# Processing Record Number 50 for : hobart
# Record Number 51 not found for : taolanaro
# Processing Record Number 52 for : tuktoyaktuk
# Processing Record Number 53 for : comodoro rivadavia
# Processing Record Number 54 for : bom jesus da lapa
# Processing Record Number 55 for : bull savanna
# Processing Record Number 56 for : tepechitlan
# Processing Record Number 57 for : itarema
# Processing Record Number 58 for : palmas
# Processing Record Number 59 for : tasiilaq
# Processing Record Number 60 for : barrow
# Processing Record Number 61 for : ilhabela
# Record Number 232 not found for : barentsburg
# Processing Record Number 233 for : souillac
# Processing Record Number 234 for : bairiki
# Processing Record Number 235 for : nha trang
# Processing Record Number 236 for : orlik
# Processing Record Number 237 for : aksarayskiy
# Record Number 238 not found for : teul
# Processing Record Number 239 for : taitung
# Processing Record Number 240 for : pangnirtung
# Processing Record Number 241 for : vostok
# Processing Record Number 242 for : palembang
# Processing Record Number 243 for : dikson
# Processing Record Number 244 for : shunyi
# Processing Record Number 245 for : sterling
# Record Number 246 not found for : tsihombe
# Processing Record Number 247 for : caravelas
# Processing Record Number 248 for : hambantota
# Processing Record Number 249 for : limbuhan
# Processing Record Number 250 for : vardo
# Processing Record Number 251 for : san mateo del mar
# Processing Record Number 252 for : turbat
# Processing Record Number 253 for : tambacounda
# Record Number 254 not found for : meyungs
# Processing Record Number 255 for : yumen
# Processing Record Number 256 for : djibo
# Processing Record Number 257 for : constitucion
# Processing Record Number 258 for : mogocha
# Processing Record Number 259 for : buala
# Processing Record Number 260 for : pevek
# Processing Record Number 261 for : sungaipenuh
# Processing Record Number 262 for : katsuura
# Processing Record Number 263 for : esperance
# Processing Record Number 264 for : thompson
# Processing Record Number 265 for : blagoyevo
# Processing Record Number 266 for : erdaojiang
# Processing Record Number 267 for : banff
# Processing Record Number 268 for : dingle
# Processing Record Number 269 for : zhukovo
# Processing Record Number 270 for : strelka
# Record Number 271 not found for : pavda
# Processing Record Number 272 for : birjand
# Processing Record Number 273 for : liberal
# Processing Record Number 274 for : ahipara
# Processing Record Number 275 for : sur
# Processing Record Number 276 for : kavaratti
# Processing Record Number 277 for : port lincoln
# Processing Record Number 278 for : cairns
# Record Number 279 not found for : maloshuyka
# Processing Record Number 280 for : nanortalik
# Processing Record Number 281 for : lubao
# Processing Record Number 282 for : ostrov
# Processing Record Number 283 for : santa isabel do rio negro
# Processing Record Number 284 for : kragero
# Processing Record Number 285 for : yar-sale
# Processing Record Number 286 for : mandalgovi
# Processing Record Number 287 for : bud
# Processing Record Number 288 for : lulea
# Processing Record Number 289 for : cayenne
# Processing Record Number 290 for : oliveira dos brejinhos
# Processing Record Number 291 for : lynn haven
# Processing Record Number 292 for : asau
# Processing Record Number 293 for : derzhavinsk
# Processing Record Number 294 for : tessalit
# Processing Record Number 295 for : lambarene
# Processing Record Number 296 for : minab
# Processing Record Number 297 for : muroto
# Processing Record Number 298 for : tongren
# Processing Record Number 299 for : omboue
# Processing Record Number 300 for : gigmoto
# Processing Record Number 301 for : ancud
# Record Number 302 not found for : tuggurt
# Processing Record Number 303 for : northam
# Processing Record Number 304 for : broome
# Processing Record Number 305 for : izhma
# Processing Record Number 306 for : khani
# Processing Record Number 307 for : berlevag
# Processing Record Number 308 for : puerto madryn
# Processing Record Number 309 for : tuatapere
# Processing Record Number 310 for : kutum
# Processing Record Number 311 for : diamantino
# Processing Record Number 312 for : ocampo
# Processing Record Number 313 for : dunedin
# Processing Record Number 314 for : kidal
# Processing Record Number 315 for : bluefield
# Processing Record Number 316 for : strai
# Processing Record Number 317 for : waihi beach
# Processing Record Number 318 for : livingston
# Processing Record Number 319 for : mosquera
# Processing Record Number 320 for : lompoc
# Processing Record Number 321 for : mundo nuevo
# Record Number 322 not found for : lolua
# Processing Record Number 323 for : darbhanga
# Processing Record Number 324 for : paka
# Processing Record Number 325 for : hobyo
# Record Number 326 not found for : jiddah
# Processing Record Number 327 for : san ramon
# Processing Record Number 328 for : haines junction
# Processing Record Number 329 for : ca mau
# Processing Record Number 330 for : namatanai
# Processing Record Number 331 for : noshiro
# Processing Record Number 332 for : iquitos
# Processing Record Number 333 for : sinnamary
# Processing Record Number 334 for : concepcion
# Processing Record Number 335 for : solnechnyy
# Processing Record Number 336 for : sao joao da barra
# Processing Record Number 337 for : imbituba
# Processing Record Number 338 for : thaton
# Processing Record Number 339 for : totana
# Processing Record Number 340 for : srandakan
# Processing Record Number 341 for : shenzhen
# Processing Record Number 342 for : beipiao
# Processing Record Number 343 for : saskylakh
# Processing Record Number 344 for : dorado
# Processing Record Number 345 for : bulancak
# Processing Record Number 346 for : necochea
# Processing Record Number 347 for : kasama
# Processing Record Number 348 for : urumqi
# Processing Record Number 349 for : meulaboh
# Processing Record Number 350 for : huarmey
# Processing Record Number 351 for : klyuchi
# Processing Record Number 352 for : luanda
# Processing Record Number 353 for : la ronge
# Processing Record Number 354 for : klichka
# Processing Record Number 355 for : koszalin
# Processing Record Number 356 for : urdoma
# Processing Record Number 357 for : hami
# Processing Record Number 358 for : hazorasp
# Processing Record Number 359 for : coos bay
# Processing Record Number 360 for : salinas
# Processing Record Number 361 for : mengyin
# Processing Record Number 362 for : kualakapuas
# Processing Record Number 363 for : bielsko-biala
# Processing Record Number 364 for : zadar
# Processing Record Number 365 for : keti bandar
# Processing Record Number 366 for : severobaykalsk
# Processing Record Number 367 for : khor
# Processing Record Number 368 for : bilma
# Processing Record Number 369 for : avera
# Processing Record Number 370 for : biloela
# Processing Record Number 371 for : aykino
# Processing Record Number 372 for : awjilah
# Processing Record Number 373 for : vila velha
# Processing Record Number 374 for : maceio
# Processing Record Number 375 for : marsh harbour
# Record Number 376 not found for : riaba
# Processing Record Number 377 for : shenjiamen
# Processing Record Number 378 for : mount gambier
# Processing Record Number 379 for : asfi
# Processing Record Number 380 for : saldanha
# Processing Record Number 381 for : gat
# Record Number 382 not found for : saleaula
# Processing Record Number 383 for : rio gallegos
# Processing Record Number 384 for : porto nacional
# Processing Record Number 385 for : mazagao
# Processing Record Number 386 for : nyagan
# Processing Record Number 387 for : guiyang
# Processing Record Number 388 for : havre-saint-pierre
# Processing Record Number 389 for : christchurch
# Processing Record Number 390 for : opuwo
# Processing Record Number 391 for : theodoriana
# Processing Record Number 392 for : sandnessjoen
# Processing Record Number 393 for : gravelbourg
# Processing Record Number 394 for : bahia blanca
# Processing Record Number 395 for : burley
# Processing Record Number 396 for : tacuarembo
# Record Number 397 not found for : marathopolis
# Processing Record Number 398 for : gumdag
# Processing Record Number 399 for : kambove
# Processing Record Number 400 for : birnin kebbi
# Processing Record Number 401 for : coahuayana
# Processing Record Number 402 for : phuntsholing
# Processing Record Number 403 for : kattivakkam
# Processing Record Number 404 for : prince rupert
# Processing Record Number 405 for : tokat
# Processing Record Number 406 for : touros
# Processing Record Number 407 for : sibolga
# Processing Record Number 408 for : san quintin
# Processing Record Number 409 for : hua hin
# Processing Record Number 410 for : bafoulabe
# Record Number 411 not found for : tambul
# Processing Record Number 412 for : sistranda
# Processing Record Number 413 for : riyadh
# Processing Record Number 414 for : lagoa
# Processing Record Number 415 for : tura
# Processing Record Number 416 for : rincon
# Processing Record Number 417 for : vieux-habitants
# Processing Record Number 418 for : ginir
# Processing Record Number 419 for : presidencia roque saenz pena
# Processing Record Number 420 for : raduzhnyy
# Processing Record Number 421 for : amapa
# Processing Record Number 422 for : okitipupa
# Processing Record Number 423 for : sisimiut
# Processing Record Number 424 for : natal
# Processing Record Number 425 for : maumere
# Processing Record Number 426 for : sabha
# Processing Record Number 427 for : matara
# Processing Record Number 428 for : vila
# Processing Record Number 429 for : zalantun
# Processing Record Number 430 for : hit
# Processing Record Number 431 for : mbuji-mayi
# Processing Record Number 432 for : elko
# Record Number 433 not found for : geresk
# Processing Record Number 434 for : aqtobe
# Record Number 435 not found for : janakpur road
# Processing Record Number 436 for : kenai
# Processing Record Number 437 for : port-de-bouc
# Processing Record Number 438 for : launceston
# Processing Record Number 439 for : shakiso
# Processing Record Number 440 for : wahiawa
# Processing Record Number 441 for : pakenham
# Processing Record Number 442 for : sao miguel do araguaia
# Processing Record Number 443 for : lamu
# Processing Record Number 444 for : yerbogachen
# Processing Record Number 445 for : samagaltay
# Processing Record Number 446 for : odessa
# Processing Record Number 447 for : srostki
# Record Number 448 not found for : maghama
# Processing Record Number 449 for : indramayu
# Record Number 450 not found for : halalo
# Processing Record Number 451 for : cockburn town
# Processing Record Number 452 for : rudnogorsk
# Record Number 453 not found for : tabukiniberu
# Processing Record Number 454 for : maua
# Processing Record Number 455 for : dom pedrito
# Processing Record Number 456 for : talnakh
# Processing Record Number 457 for : acarau
# Processing Record Number 458 for : syracuse
# Processing Record Number 459 for : vanimo
# Processing Record Number 460 for : synya
# Processing Record Number 461 for : lata
# Processing Record Number 462 for : hede
# Processing Record Number 463 for : wankaner
# Processing Record Number 464 for : ust-kuyga
# Processing Record Number 465 for : dakar
# Processing Record Number 466 for : shanhetun
# Processing Record Number 467 for : bin qirdan
# Processing Record Number 468 for : lavrentiya
# Processing Record Number 469 for : nosy varika
# Processing Record Number 470 for : mumford
# Processing Record Number 471 for : valday
# Processing Record Number 472 for : kuusamo
# Processing Record Number 473 for : banjarmasin
# Processing Record Number 474 for : roebourne
# Processing Record Number 475 for : mende
# Processing Record Number 476 for : ambilobe
# Processing Record Number 477 for : ekhabi
# Processing Record Number 478 for : erzincan
# Processing Record Number 479 for : japitan
# Processing Record Number 480 for : nador
# Processing Record Number 481 for : bereda
# Record Number 482 not found for : andevoranto
# Processing Record Number 483 for : edd
# Processing Record Number 484 for : baruun-urt
# Processing Record Number 485 for : padang
# Processing Record Number 486 for : smithers
# Processing Record Number 487 for : ruston
# Processing Record Number 488 for : deputatskiy
# Record Number 489 not found for : kazalinsk
# Processing Record Number 490 for : chiang mai
# Processing Record Number 491 for : hay river
# Processing Record Number 492 for : ulladulla
# Processing Record Number 493 for : portland
# Processing Record Number 494 for : linhares
# Processing Record Number 495 for : butte
# Processing Record Number 496 for : terrace
# Processing Record Number 497 for : geraldton
# Processing Record Number 498 for : obidos
# Processing Record Number 499 for : raga
# Processing Record Number 500 for : ozernovskiy
# Processing Record Number 501 for : santarem
# Processing Record Number 502 for : ronne
# Processing Record Number 503 for : lasa
# Processing Record Number 504 for : hofn
# Processing Record Number 505 for : tokonou
# Processing Record Number 506 for : nuuk
# Record Number 507 not found for : karkaralinsk
# Processing Record Number 508 for : burgos
# Processing Record Number 509 for : leningradskiy
# Processing Record Number 510 for : jiangyou
# Processing Record Number 511 for : bontang
# Processing Record Number 512 for : sibi
# Processing Record Number 513 for : wattegama
# Processing Record Number 514 for : bangkalan
# Processing Record Number 515 for : umaria
# Processing Record Number 516 for : lumby
# Processing Record Number 517 for : makakilo city
# Processing Record Number 518 for : mbanza-ngungu
# Record Number 519 not found for : bolshegrivskoye
# Processing Record Number 520 for : adrar
# Processing Record Number 521 for : fougamou
# Processing Record Number 522 for : yamada
# Processing Record Number 523 for : mandera
# Processing Record Number 524 for : juneau
# Processing Record Number 525 for : hervey bay
# Processing Record Number 526 for : laurinburg
# Processing Record Number 527 for : zharkent
# Processing Record Number 528 for : poum
# Processing Record Number 529 for : westport
# Processing Record Number 530 for : gombe
# Processing Record Number 531 for : taoudenni
# Processing Record Number 532 for : lorengau
# Processing Record Number 533 for : wuchang
# Processing Record Number 534 for : mahuta
# Processing Record Number 535 for : hot springs
# Processing Record Number 536 for : beachwood
# Processing Record Number 537 for : dwarka
# Processing Record Number 538 for : gobabis
# Processing Record Number 539 for : cidreira
# Processing Record Number 540 for : meadow lake
# Record Number 541 not found for : duz
# Processing Record Number 542 for : egersund
# Processing Record Number 543 for : goderich
# Processing Record Number 544 for : mendi
# Processing Record Number 545 for : brewster
# Processing Record Number 546 for : araouane
# Processing Record Number 547 for : gualaquiza
# Processing Record Number 548 for : wuwei
# Processing Record Number 549 for : marolambo
# Processing Record Number 550 for : marzuq
# Processing Record Number 551 for : berezovyy
# Processing Record Number 552 for : nizhnevartovsk
# Processing Record Number 553 for : datia
# Processing Record Number 554 for : henties bay
# Processing Record Number 555 for : petropavlovsk-kamchatskiy
# Processing Record Number 556 for : kruisfontein
# Processing Record Number 557 for : lodwar
# Processing Record Number 558 for : raudeberg
# Processing Record Number 559 for : noumea
# Processing Record Number 560 for : houma
# Processing Record Number 561 for : kirakira
# Processing Record Number 562 for : rongcheng
# Processing Record Number 563 for : montepuez
# Processing Record Number 564 for : palauig
# Processing Record Number 565 for : netivot
# Processing Record Number 566 for : zapolyarnyy
# Processing Record Number 567 for : praia da vitoria
# Processing Record Number 568 for : alice springs
# Processing Record Number 569 for : north battleford
# Processing Record Number 570 for : svetlaya
# Processing Record Number 571 for : luan
# Processing Record Number 572 for : ulaanbaatar
# Processing Record Number 573 for : kuryk
# Processing Record Number 574 for : soyo
# Processing Record Number 575 for : nsanje
# Record Number 576 not found for : satitoa
# Processing Record Number 577 for : san policarpo
# Processing Record Number 578 for : winslow
# Record Number 579 not found for : tarudant
# Processing Record Number 580 for : banda aceh
# Processing Record Number 581 for : sapa
# Processing Record Number 582 for : talcahuano
# Record Number 583 not found for : barbar
# Processing Record Number 584 for : skibbereen
# Processing Record Number 585 for : jinchang
# Processing Record Number 586 for : rock sound
# Processing Record Number 587 for : goundi
# Processing Record Number 588 for : fuerte olimpo
# Processing Record Number 589 for : sehwan
# Processing Record Number 590 for : aykhal
# Processing Record Number 591 for : kirkwood
# Processing Record Number 592 for : fairbanks
# Processing Record Number 593 for : clyde river
# Processing Record Number 594 for : road town
# Processing Record Number 595 for : suwannaphum
# Processing Record Number 596 for : ewa beach
# Processing Record Number 597 for : honiara
# Processing Record Number 598 for : baker city
# Processing Record Number 599 for : miyako
# Processing Record Number 600 for : kudahuvadhoo
# Processing Record Number 601 for : katobu
# Processing Record Number 602 for : sokoni
# Processing Record Number 603 for : turayf
# Processing Record Number 604 for : panjab
# Processing Record Number 605 for : chapeco
# Processing Record Number 606 for : olonets
# Processing Record Number 607 for : atar
# Processing Record Number 608 for : swan river
# Processing Record Number 609 for : valparaiso
# Processing Record Number 610 for : daru
# Processing Record Number 611 for : emba
# Processing Record Number 612 for : limbdi
# Processing Record Number 613 for : lalibela
# Processing Record Number 614 for : aberdeen
# Processing Record Number 615 for : kushmurun
# Processing Record Number 616 for : itamarandiba
# Record Number 617 not found for : manzil tamim
# Processing Record Number 618 for : oistins
# Processing Record Number 619 for : issoudun
# Processing Record Number 620 for : chifeng
# Record Number 621 not found for : samusu
# Processing Record Number 622 for : bani
# Processing Record Number 623 for : dire
# Processing Record Number 624 for : codrington
# Processing Record Number 625 for : godfrey
# Processing Record Number 626 for : kumluca
# Processing Record Number 627 for : sorong
# Processing Record Number 628 for : tikrit
# Processing Record Number 629 for : cheney
# Processing Record Number 630 for : trairi
# Processing Record Number 631 for : doha
# Processing Record Number 632 for : insar
# Processing Record Number 633 for : ambajogai
# Processing Record Number 634 for : katakwi
# Processing Record Number 635 for : mogadishu
# Processing Record Number 636 for : sept-iles
# Record Number 637 not found for : kamenskoye
# Processing Record Number 638 for : vikulovo
# Processing Record Number 639 for : itaueira
# Processing Record Number 640 for : mitsamiouli
# Processing Record Number 641 for : ushtobe
# Processing Record Number 642 for : tazmalt
# Processing Record Number 643 for : tianpeng
# Processing Record Number 644 for : noyabrsk
# Processing Record Number 645 for : mount isa
# Processing Record Number 646 for : kendari
# Record Number 647 not found for : barawe
# Processing Record Number 648 for : minuri
# Finished Data Retrieval

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_pd = pd.DataFrame({"City": City,
                          "Cloudiness": Cloudiness,
                          "Country": Country,
                          "Date": Date,
                          "Humidity": Humidity,
                          "Latitude": Lat,
                          "Longitude": Lng,
                          "Max Temperature" : Max_Temp,
                          "Wind Speed": Wind_Speed})
weather_pd.count()
# Out:
# City               591
# Cloudiness         591
# Country            591
# Date               591
# Humidity           591
# Latitude           591
# Longitude          591
# Max Temperature    591
# Wind Speed         591
# dtype: int64

# %%
weather_pd.head()
weather_pd.to_csv("weather_pd.csv")
# Out:
#          City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0   Carnarvon          90      AU  1584308260        88    -24.87     113.63
# 1  Rio Grande          90      BR  1584308260        73    -32.03     -52.10
# 2        Brae          48      GB  1584308261        69     60.40      -1.35
# 3    Xuanzhou          81      CN  1584308262        68     30.95     118.76
# 4    Tomatlán          87      MX  1584308199        45     19.93    -105.25
#
#    Max Temperature  Wind Speed
# 0            75.20        8.05
# 1            75.20       12.75
# 2            37.40        4.70
# 3            48.47       10.60
# 4            89.51        9.84

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
from datetime import date
today = date.today().strftime("%d/%m/%Y")

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_values = weather_pd['Latitude']
y_values = weather_pd['Max Temperature']
plt.scatter(x_values,y_values, marker="o", edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.grid(True)
plt.show()
plt.savefig("Lat_vs_Temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_values = weather_pd['Latitude']
y_values = weather_pd['Humidity']
plt.scatter(x_values,y_values, marker="o", edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs. Humidity ({today})")
plt.grid(True)
plt.show()
plt.savefig("Lat_vs_Hum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_values = weather_pd['Latitude']
y_values = weather_pd['Cloudiness']
plt.scatter(x_values,y_values, marker="o", edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.grid(True)
plt.show()
plt.savefig("Lat_vs_Cloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_values = weather_pd['Latitude']
y_values = weather_pd['Wind Speed']
plt.scatter(x_values,y_values, marker="o", edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.grid(True)
plt.show()
plt.savefig("Lat_vs_Wind.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def LinearRegressPLot(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    print(f"The r-squared is: {rvalue}")
    plt.plot(x_values,regress_values,"r-")
    plt.scatter(x_values,y_values, marker="o")
    plt.xlabel(x_values.name)
    plt.ylabel(y_values.name)
    plt.annotate(line_eq,(0,0), xycoords ='axes points' ,fontsize=15,color="red")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem= weather_pd.loc[weather_pd['Longitude']>=0]
southern_hem= weather_pd.loc[weather_pd['Longitude']<=0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
LinearRegressPLot(northern_hem['Latitude'], northern_hem['Max Temperature'])
# Out:
# The r-squared is: -0.7443001523338941

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
LinearRegressPLot(southern_hem['Latitude'], southern_hem['Max Temperature'])
# Out:
# The r-squared is: -0.7395966622608072

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
LinearRegressPLot(northern_hem['Latitude'], northern_hem['Humidity'])
# Out:
# The r-squared is: -0.02529424635912073

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
LinearRegressPLot(southern_hem['Latitude'], southern_hem['Humidity'])
# Out:
# The r-squared is: -0.04659049730750763

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
LinearRegressPLot(northern_hem['Latitude'], northern_hem['Cloudiness'])
# Out:
# The r-squared is: 0.0843041094629583

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
LinearRegressPLot(southern_hem['Latitude'], southern_hem['Cloudiness'])
# Out:
# The r-squared is: -0.03046427009449659

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
LinearRegressPLot(northern_hem['Latitude'], northern_hem['Wind Speed'])
# Out:
# The r-squared is: 0.06242040461927589

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
LinearRegressPLot(southern_hem['Latitude'], southern_hem['Wind Speed'])
# Out:
# The r-squared is: 0.15838634052899017
